# %% [markdown]
# ## Programiranje kompleksnijih sistema

# %% [markdown]
# Poredjenje rjesavanja sistema obicnih diferencijalnih jednacina u nekoliko jezika, izvor:
# [https://en.wikipedia.org/wiki/Lorenz_system](https://en.wikipedia.org/wiki/Lorenz_system)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 28.0
sigma = 10.0
beta = 8.0 / 3.0

def f(state, t):
  x, y, z = state  # unpack the state vector
  return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  # derivatives

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(states[:,0], states[:,1], states[:,2])
plt.show()

# %% [markdown]
# ### Kopiraj modelica kod u OMNotebook i uporedi rezultate - tamo je i vrijeme na plotu

# %% [markdown]
# ## [Multiscale Solar Water Heating](https://github.com/LBNL-ETA/MSWH)
#
# [Web aplicakija](http://127.0.0.1:8000/)
#
# Vidi wiki stranicu o instalaciji
#
# [Prodji kroz dokumentaciju i sadrzaj paketa](https://lbnl-eta.github.io/MSWH/)
#
# Prodji kroz svesku `MSWH System Tool - Playground.ipynb`, nalazi se u folderu `scripts`

# %% [markdown]
# ## Modelica
#
# OMEdit, look at a few examples in OMNotebook
#
# Dymola Trial
#
# CDL
#
# https://mbe.modelica.university/behavior/equations/physical/
#
# [Docker for JModelica](https://github.com/lbl-srg/docker-ubuntu-jmodelica) - faster solvers
